# %% [markdown]
# # Token Embedding ( Vector Embedding)

# %% [markdown]
# ### Some companies has pre-trained token embedding models like word2vec-google-news-300 by google trianed on 100 million words and 300 dimensions..

# %%
# !pip install gensim

# %%
import gensim.downloader as api
model = api.load("word2vec-google-news-300")  #Download the model and return as object ready for use
# Out:
# [=================================-----------------] 67.9% 1129.5/1662.8MB downloaded

# %%
word_vectors=model

#Let us look how the vector embedding of a word looks like
print(word_vectors['computers']) # Example: Accessing the vector for the word 'computer'
# Out:
# [ 0.32421875 -0.24316406  0.11523438  0.25976562 -0.18847656  0.10595703
#  -0.10205078  0.10693359  0.28710938  0.01428223  0.0100708  -0.20214844
#   0.19238281  0.07714844 -0.03686523  0.06933594 -0.0013504   0.26757812
#   0.12011719  0.02746582 -0.0072937  -0.04443359  0.15625     0.10693359
#   0.1640625  -0.07177734  0.02355957 -0.03930664 -0.05004883 -0.17480469
#  -0.06054688 -0.10839844 -0.17382812  0.01843262  0.14160156 -0.4140625
#  -0.43554688 -0.12792969  0.1484375  -0.04882812 -0.11914062  0.23046875
#   0.265625    0.10400391  0.27929688  0.06933594 -0.03881836  0.31640625
#  -0.40625     0.05712891 -0.01324463 -0.09960938  0.05737305 -0.18945312
#  -0.15039062  0.23632812 -0.05102539 -0.17871094 -0.21972656  0.14746094
#   0.16308594  0.04736328 -0.13183594  0.22070312 -0.04003906  0.05517578
#  -0.2734375   0.42773438 -0.25585938  0.06591797  0.05419922 -0.25
#   0.14453125 -0.00531006 -0.08984375 -0.01312256  0.08349609 -0.203125
# ...

# %%
print(word_vectors['cat'].shape)
# Out:
# (300,)

# %% [markdown]
# ### Similar words
# ### King + Woman - Man =?

# %%
# Example of using most_similar
print(word_vectors.most_similar(positive=['king', 'woman'], negative=['man'], topn=10))
# Out:
# [('queen', 0.7118192911148071), ('monarch', 0.6189674735069275), ('princess', 0.5902431011199951), ('crown_prince', 0.549946129322052), ('prince', 0.5377321243286133), ('kings', 0.5236843824386597), ('Queen_Consort', 0.5235944390296936), ('queens', 0.5181134343147278), ('sultan', 0.5098593235015869), ('monarchy', 0.5087411403656006)]

# %% [markdown]
# ### Let us check the similarity b/w a few pair of words

# %%
# Example of calculating similarity
print(word_vectors.similarity('woman', 'man'))
print(word_vectors.similarity('king', 'queen'))
print(word_vectors.similarity('uncle', 'aunt'))
print(word_vectors.similarity('boy', 'girl'))
print(word_vectors.similarity('nephew', 'niece'))
print(word_vectors.similarity('paper', 'water'))
# Out:
# 0.76640123
# 0.6510957
# 0.76434743
# 0.8543272
# 0.7594367
# 0.11408083

# %%
### Most

# %%
import numpy as np
import pandas as pd

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
# Out:
# NumPy: 1.26.4
# Pandas: 2.1.4

# %%
import pytesseract
from PIL import Image

print(pytesseract.get_tesseract_version())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# 5.5.0.20241111

# %%
text = pytesseract.image_to_string(Image.open("marks_sheet_1.jpg"), lang="eng")

# %%
print(text)
# Out:
# Tita —aog
# NR-Siaray -CUM.
# TEC
# cial connec ae "a
# 0416173
# Weators
#
# He | Regular Privatg
# 96/13423/4465 EGU
#
# ‘ecard. Sunn
#  ¢ St RAIVATI Dey
# DARSHAN singly
# Swrose date of nant
# SNETEEN NINETY ning: 08-1999)
# 2014 ay Te waa, Ferenc 3,
# Fomeenike. a ARGH SMARAK INT cor GONDA ati
# bE Ferro aan Pt © (with the rane
# SS Freeper 8 (with the on datais)
# Subject Mi
#
# 1 att High Sci00| Exam,
# IGARH
# ate
# ex Marks
# HIND too
# ENGLisH
#
# 100
# MATHEMATICS
#
# &
# "NCH Held nh Marchiaga 2014
#
# SOCIAL Science
# SCIENCE
# DRAWING

# %%
import fitz

# %%
doc = fitz.open("usama-attique-resume.pdf")
for page in doc:
    print(page.get_text())
# Out:
# Tushar Vashishth
# AI Engineer | Machine Learning & Deep Learning Specialist
# tusharvashishth469@gmail.com
#  | +919548189388
#  | Mathura, Uttar Pradesh
#  | Tushar Vashishth
#
# vashishthtushar
#  | https://sites.google.com/view/tusharvas-portfolio
#
# PROFESSIONAL SUMMARY
# AI/ML and Data Science professional specializing in Machine Learning, Deep Learning, and Generative AI,
# including LLMs and Retrieval-Augmented Generation (RAG). Strong proficiency in Python, PyTorch,
# TensorFlow, model development, and explainable AI techniques.
# EDUCATION
# Minor in Data Science ( AI and ML ), Indian Institute of Technology Mandi
# 07/2024 – 12/12/2025
# Bachelor of Science, DR. Bhimrao Ambedkar University, Agra
# 05/2019 – 09/2023
# SKILLS
# Technical Skills: Machine Learning, Deep Learning, Predictive Modeling, Natural Language Processing
# (NLP),Large Language model(LLM), Retrieval-Augmented Generation (RAG), Model Evaluation &
# Optimization
# Tools & Programming:  Python, TensorFlow, Keras, PyTorch, Scikit-learn, Pandas, NumPy, OpenCV, SQL, Git/​
# GitHub, Streamlit, Flask
# Soft skills: Teamwork, Communication, Problem-solving, Adaptability, Time management, Critical thinking
# PROJECTS
# LithoSense, An Explainable AI Tool for Gallstone Risk Prediction
# •Designed and developed an end-to-end ML pipeline for medical risk prediction.
# •Performed EDA, data preprocessing, and feature engineering using pandas and NumPy, trained and
# calibrated an XGBoost model achieving high predictive performance.
# •Implemented SHAP-based explainability for global and local feature interpretation, deployed the model via
# an interactive Streamlit application.
# •Integrated Hugging Face LLM APIs to generate automated clinical insights, and lifestyle recommendation.
# • versioned code on GitHub: Link⁠
# Customer Churn Prediction Dashboard
# •Built an interactive Streamlit app to predict telecom customer churn using a trained RandomForest model.
# •Performed EDA, preprocessing, and feature engineering with Python, pandas, and scikit-learn.
# •Applied SHAP to interpret feature impact and visualize churn drivers for individual customers ; versioned
# code on GitHub : Link⁠
# PROFESSIONAL EXPERIENCE
# Full Stack Developer Intern, CodeAlpha
# •Completed a one-month virtual Full Stack (MERN) internship, developing web
# apps with authentication, CRUD operations, dashboards, and REST APIs.
# 03/2025 – 04/2025
# Remote
# Teaching Instructor, Local Coaching Institute ( Sarda Institute)
# •Taught Mathematics and Science to high-school students using analytical methods
# and real-life examples.
# 05/2023 – 09/2023
# Dehradun, India
# CERTIFICATES
# Full Stack Web Development [MERN]- Apna_College⁠
# , Hackathon – Xto10X Hackathon (by Masai)⁠
